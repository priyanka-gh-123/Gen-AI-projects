# %%
import gradio as gr
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import torch
import warnings
warnings.filterwarnings('ignore')

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# The image processor of type `BlipImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# C:\Users\ghada\AppData\Local\Programs\Python\Python313\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ghada\.cache\huggingface\hub\models--Salesforce--blip-image-captioning-large. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Loading weights:   0%|          | 0/616 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie text_decoder.bert.embeddings.word_embeddings.weight to text_decoder.cls.predictions.decoder.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# BlipForConditionalGeneration LOAD REPORT from: Salesforce/blip-image-captioning-large
# Key                                       | Status     |  |
# ------------------------------------------+------------+--+-
# text_decoder.bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
from PIL import Image
import torch
def generate_caption(image):
    print(type(image))   # should show PIL.Image.Image
    
    inputs = processor(image, return_tensors="pt")

    with torch.no_grad():
        out = model.generate(**inputs)

    caption = processor.decode(out[0], skip_special_tokens=True)
    return caption

# %%
import gradio as gr

iface = gr.Interface(
    fn=generate_caption,
    inputs=gr.Image(type="pil"),
    outputs="text"
)

iface.launch()(share=True, debug=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 9
#       1 import gradio as gr
#       3 iface = gr.Interface(
#       4     fn=generate_caption,
#       5     inputs=gr.Image(type="pil"),
#       6     outputs="text"
#       7 )
# ----> 9 iface.launch()(share=True, debug=True)
#
# TypeError: 'TupleNoPrint' object is not callable
# Traceback (most recent call last):
#   File "C:\Users\ghada\AppData\Local\Programs\Python\Python313\Lib\site-packages\gradio\queueing.py", line 785, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#     )
#     ^
#   File "C:\Users\ghada\AppData\Local\Programs\Python\Python313\Lib\site-packages\gradio\route_utils.py", line 358, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<11 lines>...
#     )
#     ^
#   File "C:\Users\ghada\AppData\Local\Programs\Python\Python313\Lib\site-packages\gradio\blocks.py", line 2162, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#     )
#     ^
#   File "C:\Users\ghada\AppData\Local\Programs\Python\Python313\Lib\site-packages\gradio\blocks.py", line 1634, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         fn, *processed_input, limiter=self.limiter
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\ghada\AppData\Local\Programs\Python\Python313\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         func, args, abandon_on_cancel=abandon_on_cancel, limiter=limiter
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\ghada\AppData\Local\Programs\Python\Python313\Lib\site-packages\anyio\_backends\_asyncio.py", line 2461, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\ghada\AppData\Local\Programs\Python\Python313\Lib\site-packages\anyio\_backends\_asyncio.py", line 962, in run
#     result = context.run(func, *args)
#   File "C:\Users\ghada\AppData\Local\Programs\Python\Python313\Lib\site-packages\gradio\utils.py", line 1050, in wrapper
#     response = f(*args, **kwargs)
#   File "C:\Users\ghada\AppData\Local\Temp\ipykernel_4512\2364179400.py", line 3, in generate_caption
#     raw_image = Image.open(image).convert("RGB")
#                 ~~~~~~~~~~^^^^^^^
#   File "C:\Users\ghada\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\Image.py", line 3516, in open
#     prefix = fp.read(16)
#              ^^^^^^^
# AttributeError: 'Image' object has no attribute 'read'

# %%
# !pip install --upgrade gradio
# !pip install pyngrok
# Out:
# Requirement already satisfied: gradio in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (6.10.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (4.8.0)
# Requirement already satisfied: audioop-lts<1.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.135.2)
# Requirement already satisfied: ffmpy in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.4.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (2.4.0)
# Requirement already satisfied: groovy~=0.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.3.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.3.0)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (1.7.2)
# Requirement already satisfied: jinja2<4.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (3.1.5)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (2.3.0)
# Requirement already satisfied: orjson~=3.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (3.11.7)
# Requirement already satisfied: packaging in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (2.3.0)
# Requirement already satisfied: pillow<13.0,>=8.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (11.2.1)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (2.12.5)
# Requirement already satisfied: pydub in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.0.22)
# Requirement already satisfied: pytz>=2017.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.24.1)
# Requirement already satisfied: typing-extensions~=4.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio) (0.42.0)
# Requirement already satisfied: fsspec in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gradio-client==2.4.0->gradio) (2026.2.0)
# Requirement already satisfied: idna>=2.8 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock>=3.10.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.41.5)
# Requirement already satisfied: click>=8.2.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer<1.0,>=0.12->gradio) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer<1.0,>=0.12->gradio) (14.0.0)
# Requirement already satisfied: colorama in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click>=8.2.1->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/gradio/
# Requirement already satisfied: pyngrok in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (7.5.1)
# Requirement already satisfied: PyYAML>=5.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pyngrok) (6.0.2)
